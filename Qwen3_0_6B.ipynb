# %% [markdown]
# <a href="https://colab.research.google.com/github/nour-tkitek/conference-website-template/blob/master/Qwen3_0_6B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/Qwen/Qwen3-0.6B
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/Qwen/Qwen3-0.6B)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="Qwen/Qwen3-0.6B")
messages = [
    {"role": "user", "content": "Who are you?"},
]
pipe(messages)
# Out:
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors: reconstructing file:   0%|          |  0.00B / 1.50GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/9.73k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json: reconstructing file:   0%|          |  0.00B / 11.4MB
# tokenizer.json: downloading bytes:           |  0.00B
# ...

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-0.6B")
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen3-0.6B", device_map="auto")
messages = [
    {"role": "user", "content": "Who are you?"},
]
inputs = tokenizer.apply_chat_template(
	messages,
	add_generation_prompt=True,
	tokenize=True,
	return_dict=True,
	return_tensors="pt",
).to(model.device)

outputs = model.generate(**inputs, max_new_tokens=40)
print(tokenizer.decode(outputs[0][inputs["input_ids"].shape[-1]:]))
# Out:
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# <think>
# Okay, the user asked, "Who are you?" I need to respond appropriately. First, I should acknowledge their question and provide a friendly answer. I can mention that I'm a language

# %%
question = "What is RAG in artificial intelligence? Explain it simply."

messages = [
    {"role": "user", "content": question}
]

inputs = tokenizer.apply_chat_template(
    messages,
    add_generation_prompt=True,
    tokenize=True,
    return_dict=True,
    return_tensors="pt",
).to(model.device)

outputs = model.generate(
    **inputs,
    max_new_tokens=200
)

answer = tokenizer.decode(
    outputs[0][inputs["input_ids"].shape[-1]:],
    skip_special_tokens=True
)

print(answer)
# Out:
# <think>
# Okay, so I need to explain RAG in AI. Let me start by recalling what I know. RAG stands for Retrieval-Augmented Generation. From what I remember, it's a technique that combines the use of information retrieval with the generation of text. But I should make sure I'm not mixing things up with other AI concepts.
#
# First, I think RAG works by first retrieving relevant information from a database or a large text collection, which is then used to generate the final output. That makes sense because if you just generate from scratch, you might not get the best results. For example, if you have a document about climate change and you want to generate a summary, RAG would first find the relevant part and then create a summary from that.
#
# Wait, but sometimes I heard that RAG is part of a larger system like LLMs. Like, maybe it's a way to use an LLM to generate text by first retrieving the necessary information. So R

# %%
question = "Explain Large Language Models to me like I am a beginner."

# %%
question = "What is the difference between RAG and fine-tuning?"

# %%
messages = [
    {"role": "user", "content": question}
]

inputs = tokenizer.apply_chat_template(
    messages,
    tokenize=True,
    add_generation_prompt=True,
    return_dict=True,
    return_tensors="pt",
    enable_thinking=False
).to(model.device)

outputs = model.generate(
    **inputs,
    max_new_tokens=200
)

answer = tokenizer.decode(
    outputs[0][inputs["input_ids"].shape[-1]:],
    skip_special_tokens=True
)

print(answer)
# Out:
# The difference between **RAG (Retrieval-Augmented Generation)** and **fine-tuning** is that **RAG** is a technique used to improve the performance of AI models by combining **retrieval** and **generative** tasks, while **fine-tuning** refers to the process of training a pre-trained model on a specific dataset to adapt it to a new task. Here's a breakdown:
#
# ### 1. **RAG (Retrieval-Augmented Generation)**
# - **Purpose**: Enhances the performance of a model by combining retrieval (to find relevant information) with generation (to create text).
# - **Mechanism**:
#   - The model first retrieves relevant information from a database.
#   - Then, the model generates text based on the retrieved content.
# - **Example**: Using a document database to find relevant articles and generate a summary or response.
# - **Use Case**: For tasks like text summarization, article writing, or answering questions where information is required
